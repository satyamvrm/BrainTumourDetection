# %% [markdown]
# # Detecting Brain Tumors in MRIs using a Convolutional Neural Network with Transfer Learning

# %% [markdown]
# 1. Introduction
#     * 1.1 Brief overview of task
#     * 1.2 Purpose of the Project
#     * 1.3 Brief description of dataset
#
# 2. Downloading the Data
#     * 2.1 Downloading libaries
#     * 2.2 Downloading the images
#
# 3. Processing the Images
#     * 3.1 Changing pixel value
#     * 3.2 Visualization
#
# 4. Convolutional Neural Network
#     * 4.1 Split data into train, validation, test
#     * 4.2 Creating our baseline model
#     * 4.3 Adding data agumentation
#     * 4.4 Adding a pretrained model
#
# 5. Results
#     * 5.1 Results table
#
# 6. Conclusion
#     * 6.1 Summary
#     * 6.2 Brief thoughts on results
#     * 6.3 Futrue work

# %% [markdown]
# # 1. Introduction

# %% [markdown]
# ## 1.1 Brief overview of task
#
# The brain is one of, if not the most important part of our body. Any type of disease involving the brain is very serious. It is very important to detect a tumor not only accurately but as early as possible. Our task will be to take MRI images and accurately predict if the image of the brain has a tumor.

# %% [markdown]
# To better understand our task below is a brief explanation of brain tumors from the Mayo Clinic:
#
# *A brain tumor is a mass or growth of abnormal cells in your brain.*
#
# *Many different types of brain tumors exist. Some brain tumors are noncancerous (benign), and some brain tumors are cancerous (malignant). Brain tumors can begin in your brain (primary brain tumors), or cancer can begin in other parts of your body and spread to your brain as secondary (metastatic) brain tumors.*
#
# *How quickly a brain tumor grows can vary greatly. The growth rate as well as the location of a brain tumor determines how it will affect the function of your nervous system.*
#
# *Brain tumor treatment options depend on the type of brain tumor you have, as well as its size and location.*

# %% [markdown]
# ## 1.2 Purpose of the project
#
# The purpose of this project will be to create a convolutional neural network that can classify a MRI of the brain into two catagories: tumor, no tumor. We will start with a baseline model. From there we use data agumentation to add data. Then we will apply transfer learning to improve the accuracy. The idea is that the accuracy will improve with each step.

# %% [markdown]
# ## 1.3 Brief description of dataset
#
# Unfornately we do not have much information about this dataset and where it comes from. This is a limitation to the project but we will still be able to use this data to give us a good idea of how to detect tumors using a convolutional neural network. Furture studies will involve more rigorous and larger dataset.

# %% [markdown]
# # 2. Downloading the Data

# %% [markdown]
# ## 2.1 Downloading the libaries

# %%
#importing libaries
import numpy as np 
import pandas as pd
import random as rd
import os

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

from PIL import Image

from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers.experimental import preprocessing
from keras.metrics import accuracy
from keras.applications.vgg16 import VGG16

#setting seed for reproducability
from numpy.random import seed
seed(25)
tf.random.set_seed(50)

# %% [markdown]
# ## 2.2 Downloading the images

# %%
# 0 - Normal
# 1 - Tumor

data = [] #creating a list for images
paths = [] #creating a list for paths
labels = [] #creating a list to put our 0 or 1 labels

#staring with the images that have tumors
for r, d, f in os.walk(r'../input/brain-mri-images-for-brain-tumor-detection/yes'):
    for file in f:
        if '.jpg' in file:
            paths.append(os.path.join(r, file))

for path in paths:
    img = Image.open(path)
    img = img.resize((256,256))
    img = np.array(img)
    if(img.shape == (256,256,3)):
        data.append(np.array(img))
        labels.append(1)

#now working with the images with no tumors        
paths = []
for r, d, f in os.walk(r"../input/brain-mri-images-for-brain-tumor-detection/no"):
    for file in f:
        if '.jpg' in file:
            paths.append(os.path.join(r, file))

for path in paths:
    img = Image.open(path)
    img = img.resize((256,256))
    img = np.array(img)
    if(img.shape == (256,256,3)):
        data.append(np.array(img))
        labels.append(0)
        
data = np.array(data)
data.shape

labels = np.array(labels)
labels = labels.reshape(139,1)

print('data shape is:', data.shape)
print('labels shape is:', labels.shape)
# Out:
# data shape is: (139, 256, 256, 3)
# labels shape is: (139, 1)

# %% [markdown]
# # 3. Processing the images

# %%
#we have 139 images with 128 height, 128 weight, RGB color channel
print(data.shape)
# Out:
# (139, 256, 256, 3)

# %% [markdown]
# ## 3.1 Changing pixel values

# %% [markdown]
# Each pixel has a value between 255 and 0. We will reduce this down to 1 and 0 in order to help the neural network converge quicker.

# %%
#getting the max of the array
print(np.max(data))
#getting the min of the array
print(np.min(data))
# Out:
# 255
# 0

# %%
#reducing the data to between 1 and 0
data = data / 255.00
#getting the max of the array
print(np.max(data))
#getting the min of the array
print(np.min(data))
# Out:
# 1.0
# 0.0

# %% [markdown]
# ## 3.2 Visualizing the images

# %%
for i in range(5):
    fig = plt.figure(figsize=(70,70))
    plt.subplot(5,5,i+1)
    image = plt.imshow(data[i])
    plt.show(image)

# %% [markdown]
# # 4 Model

# %% [markdown]
# ## 4.1 Creating training and test sets

# %% [markdown]
# Before we create our model we will split up the data into traing sets and test sets with 70% going to training and 30% going to testing.

# %%
x_train,x_test,y_train,y_test = train_test_split(data, labels, test_size=0.3, shuffle=True, random_state=10)

# %%
print("shape of our training data:",x_train.shape)
print("shape of our training labels:",y_train.shape)
print("shape of our test data:",x_test.shape)
print("shape of our test labels:",y_test.shape)
# Out:
# shape of our training data: (97, 256, 256, 3)
# shape of our training labels: (97, 1)
# shape of our test data: (42, 256, 256, 3)
# shape of our test labels: (42, 1)

# %% [markdown]
# ## 4.2 Creating our baseline model

# %% [markdown]
# We will start with creating a sequential model set up for binary classification using the keras libary.

# %%
model = keras.Sequential([
    
    layers.Conv2D(filters=32, kernel_size=(5,5), activation="relu", padding='same', input_shape=[256, 256, 3]),
    layers.MaxPool2D(),
    
    layers.Conv2D(filters=64, kernel_size=(3,3), activation="relu", padding='same'),
    layers.MaxPool2D(),
    
    layers.Conv2D(filters=64, kernel_size=(3,3), activation="relu", padding='same'),
    layers.MaxPool2D(),
    
    layers.Conv2D(filters=128, kernel_size=(3,3), activation="relu", padding='same'),
    layers.MaxPool2D(),
    
    layers.Conv2D(filters=128, kernel_size=(3,3), activation="relu", padding='same'),
    layers.MaxPool2D(),
    
    layers.Flatten(),
    layers.Dropout(.25),
    layers.Dense(units=256, activation="relu"),
    layers.Dense(units=1, activation="sigmoid"),
])
model._name="Brain_Tumor_Detection"

model.summary()
# Out:
# Model: "Brain_Tumor_Detection"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_34 (Conv2D)          (None, 256, 256, 32)      2432
#
#  max_pooling2d_34 (MaxPoolin  (None, 128, 128, 32)     0
#  g2D)
#
#  conv2d_35 (Conv2D)          (None, 128, 128, 64)      18496
#
#  max_pooling2d_35 (MaxPoolin  (None, 64, 64, 64)       0
#  g2D)
#
#  conv2d_36 (Conv2D)          (None, 64, 64, 64)        36928
#
#  max_pooling2d_36 (MaxPoolin  (None, 32, 32, 64)       0
#  g2D)
#
#  conv2d_37 (Conv2D)          (None, 32, 32, 128)       73856
#
#  max_pooling2d_37 (MaxPoolin  (None, 16, 16, 128)      0
#  g2D)
#
#  conv2d_38 (Conv2D)          (None, 16, 16, 128)       147584
#
#  max_pooling2d_38 (MaxPoolin  (None, 8, 8, 128)        0
#  g2D)
#
#  flatten_15 (Flatten)        (None, 8192)              0
#
#  dropout_15 (Dropout)        (None, 8192)              0
#
#  dense_30 (Dense)            (None, 256)               2097408
#
#  dense_31 (Dense)            (None, 1)                 257
#
# =================================================================
# Total params: 2,376,961
# Trainable params: 2,376,961
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(epsilon=0.01),
    loss='binary_crossentropy',
    metrics=['accuracy']
)

#including early stopping to prevent overfitting
early_stopping = keras.callbacks.EarlyStopping(
    patience=10,
    min_delta=0.001,
    restore_best_weights=True,
)

# %%
history = model.fit(
    x = x_train,
    y = y_train,
    validation_data= (x_test,y_test),
    batch_size = 64,
    epochs=40,
    callbacks=[early_stopping],
    verbose=(2),
)
# Out:
# Epoch 1/40
# 2/2 - 13s - loss: 0.6905 - accuracy: 0.6392 - val_loss: 0.6936 - val_accuracy: 0.4762 - 13s/epoch - 6s/step
# Epoch 2/40
# 2/2 - 10s - loss: 0.6907 - accuracy: 0.5979 - val_loss: 0.6932 - val_accuracy: 0.5000 - 10s/epoch - 5s/step
# Epoch 3/40
# 2/2 - 10s - loss: 0.6896 - accuracy: 0.6186 - val_loss: 0.6926 - val_accuracy: 0.5000 - 10s/epoch - 5s/step
# Epoch 4/40
# 2/2 - 11s - loss: 0.6888 - accuracy: 0.5876 - val_loss: 0.6918 - val_accuracy: 0.5952 - 11s/epoch - 5s/step
# Epoch 5/40
# 2/2 - 10s - loss: 0.6874 - accuracy: 0.5979 - val_loss: 0.6909 - val_accuracy: 0.5714 - 10s/epoch - 5s/step
# Epoch 6/40
# 2/2 - 10s - loss: 0.6886 - accuracy: 0.5670 - val_loss: 0.6899 - val_accuracy: 0.5714 - 10s/epoch - 5s/step
# Epoch 7/40
# 2/2 - 11s - loss: 0.6852 - accuracy: 0.6701 - val_loss: 0.6891 - val_accuracy: 0.5714 - 11s/epoch - 5s/step
# Epoch 8/40
# 2/2 - 10s - loss: 0.6834 - accuracy: 0.6701 - val_loss: 0.6882 - val_accuracy: 0.5714 - 10s/epoch - 5s/step
# Epoch 9/40
# 2/2 - 11s - loss: 0.6852 - accuracy: 0.6495 - val_loss: 0.6871 - val_accuracy: 0.5476 - 11s/epoch - 5s/step
# Epoch 10/40
# 2/2 - 11s - loss: 0.6805 - accuracy: 0.6804 - val_loss: 0.6861 - val_accuracy: 0.5476 - 11s/epoch - 5s/step
# Epoch 11/40
# 2/2 - 10s - loss: 0.6790 - accuracy: 0.6804 - val_loss: 0.6850 - val_accuracy: 0.5476 - 10s/epoch - 5s/step
# Epoch 12/40
# 2/2 - 10s - loss: 0.6769 - accuracy: 0.7010 - val_loss: 0.6841 - val_accuracy: 0.5476 - 10s/epoch - 5s/step
# Epoch 13/40
# 2/2 - 11s - loss: 0.6750 - accuracy: 0.7113 - val_loss: 0.6832 - val_accuracy: 0.5476 - 11s/epoch - 5s/step
# Epoch 14/40
# 2/2 - 11s - loss: 0.6759 - accuracy: 0.7320 - val_loss: 0.6822 - val_accuracy: 0.5476 - 11s/epoch - 5s/step
# Epoch 15/40
# 2/2 - 10s - loss: 0.6708 - accuracy: 0.7423 - val_loss: 0.6812 - val_accuracy: 0.5476 - 10s/epoch - 5s/step
# Epoch 16/40
# 2/2 - 11s - loss: 0.6735 - accuracy: 0.7216 - val_loss: 0.6802 - val_accuracy: 0.5476 - 11s/epoch - 5s/step
# Epoch 17/40
# 2/2 - 10s - loss: 0.6700 - accuracy: 0.7216 - val_loss: 0.6790 - val_accuracy: 0.5476 - 10s/epoch - 5s/step
# Epoch 18/40
# 2/2 - 10s - loss: 0.6641 - accuracy: 0.7526 - val_loss: 0.6780 - val_accuracy: 0.5476 - 10s/epoch - 5s/step
# Epoch 19/40
# 2/2 - 11s - loss: 0.6637 - accuracy: 0.7732 - val_loss: 0.6770 - val_accuracy: 0.5476 - 11s/epoch - 5s/step
# Epoch 20/40
# 2/2 - 10s - loss: 0.6614 - accuracy: 0.7320 - val_loss: 0.6759 - val_accuracy: 0.5476 - 10s/epoch - 5s/step
# Epoch 21/40
# 2/2 - 10s - loss: 0.6604 - accuracy: 0.7320 - val_loss: 0.6750 - val_accuracy: 0.5476 - 10s/epoch - 5s/step
# Epoch 22/40
# 2/2 - 11s - loss: 0.6540 - accuracy: 0.7629 - val_loss: 0.6737 - val_accuracy: 0.5238 - 11s/epoch - 6s/step
# Epoch 23/40
# 2/2 - 11s - loss: 0.6514 - accuracy: 0.7526 - val_loss: 0.6725 - val_accuracy: 0.5238 - 11s/epoch - 5s/step
# Epoch 24/40
# 2/2 - 10s - loss: 0.6451 - accuracy: 0.7320 - val_loss: 0.6709 - val_accuracy: 0.5238 - 10s/epoch - 5s/step
# Epoch 25/40
# 2/2 - 11s - loss: 0.6407 - accuracy: 0.7732 - val_loss: 0.6691 - val_accuracy: 0.5238 - 11s/epoch - 5s/step
# Epoch 26/40
# 2/2 - 10s - loss: 0.6385 - accuracy: 0.7423 - val_loss: 0.6681 - val_accuracy: 0.5238 - 10s/epoch - 5s/step
# Epoch 27/40
# 2/2 - 10s - loss: 0.6285 - accuracy: 0.7423 - val_loss: 0.6678 - val_accuracy: 0.5476 - 10s/epoch - 5s/step
# Epoch 28/40
# 2/2 - 11s - loss: 0.6240 - accuracy: 0.7629 - val_loss: 0.6685 - val_accuracy: 0.5476 - 11s/epoch - 5s/step
# Epoch 29/40
# 2/2 - 10s - loss: 0.6147 - accuracy: 0.7526 - val_loss: 0.6695 - val_accuracy: 0.5000 - 10s/epoch - 5s/step
# Epoch 30/40
# 2/2 - 10s - loss: 0.6141 - accuracy: 0.7526 - val_loss: 0.6704 - val_accuracy: 0.5000 - 10s/epoch - 5s/step
# Epoch 31/40
# 2/2 - 10s - loss: 0.6084 - accuracy: 0.7629 - val_loss: 0.6706 - val_accuracy: 0.5000 - 10s/epoch - 5s/step
# Epoch 32/40
# 2/2 - 10s - loss: 0.5950 - accuracy: 0.7629 - val_loss: 0.6723 - val_accuracy: 0.5000 - 10s/epoch - 5s/step
# Epoch 33/40
# 2/2 - 10s - loss: 0.5859 - accuracy: 0.7835 - val_loss: 0.6736 - val_accuracy: 0.5000 - 10s/epoch - 5s/step
# Epoch 34/40
# 2/2 - 10s - loss: 0.5760 - accuracy: 0.7732 - val_loss: 0.6749 - val_accuracy: 0.5000 - 10s/epoch - 5s/step
# Epoch 35/40
# 2/2 - 11s - loss: 0.5603 - accuracy: 0.7629 - val_loss: 0.6784 - val_accuracy: 0.5000 - 11s/epoch - 5s/step
# Epoch 36/40
# 2/2 - 10s - loss: 0.5441 - accuracy: 0.7732 - val_loss: 0.6862 - val_accuracy: 0.5000 - 10s/epoch - 5s/step
# Epoch 37/40
# 2/2 - 10s - loss: 0.5424 - accuracy: 0.7526 - val_loss: 0.7021 - val_accuracy: 0.5000 - 10s/epoch - 5s/step

# %%
history_frame = pd.DataFrame(history.history)
history_frame.loc[:, ['loss','val_loss']].plot()
history_frame.loc[:, ['accuracy','val_accuracy']].plot();

# %%
pred = model.predict(x_test)

for i in range(len(pred)):
    if pred[i] > 0.5:
        pred[i] = 1
    else:
        pred[i] = 0
     
pred = pred.astype(int)
# Out:
# 2/2 [==============================] - 1s 259ms/step

# %%
#creating a classification report
classification_report(y_test, pred)
# Out:
# '              precision    recall  f1-score   support\n\n           0       0.44      0.47      0.46        17\n           1       0.62      0.60      0.61        25\n\n    accuracy                           0.55        42\n   macro avg       0.53      0.54      0.53        42\nweighted avg       0.55      0.55      0.55        42\n'

# %% [markdown]
# ## 4.3 Adding data agumentation

# %% [markdown]
# Here we will add a technique called data agumentation. We will be adding a layer that flips our images horizontaly creating more data for our model to train on.

# %%
model = keras.Sequential([
    
    preprocessing.RandomFlip('horizontal'), # flip left-to-right
    
    layers.Conv2D(filters=32, kernel_size=(5,5), activation="relu", padding='same', input_shape=[256, 256, 3]),
    layers.MaxPool2D(),
    
    layers.Conv2D(filters=64, kernel_size=(3,3), activation="relu", padding='same'),
    layers.MaxPool2D(),
    
    layers.Conv2D(filters=128, kernel_size=(3,3), activation="relu", padding='same'),
    layers.MaxPool2D(),
    
    layers.Conv2D(filters=128, kernel_size=(3,3), activation="relu", padding='same'),
    layers.MaxPool2D(),
    
    layers.Conv2D(filters=128, kernel_size=(3,3), activation="relu", padding='same'),
    layers.MaxPool2D(),
    
    layers.Flatten(),
    layers.Dropout(.25),
    layers.Dense(units=256, activation="relu"),
    layers.Dense(units=1, activation="sigmoid"),
])

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(epsilon=0.01),
    loss='binary_crossentropy',
    metrics=['accuracy']
)

#including early stopping to revent overfitting
early_stopping = keras.callbacks.EarlyStopping(
    patience=30,
    min_delta=0.001,
    restore_best_weights=True,
)

# %%
history = model.fit(
    x = x_train,
    y = y_train,
    validation_data= (x_test,y_test),
    batch_size = 64,
    epochs=40,
    callbacks=[early_stopping],
    verbose=(2),
)
# Out:
# Epoch 1/40
# 2/2 - 15s - loss: 0.6917 - accuracy: 0.5361 - val_loss: 0.6942 - val_accuracy: 0.5000 - 15s/epoch - 7s/step
# Epoch 2/40
# 2/2 - 11s - loss: 0.6920 - accuracy: 0.5567 - val_loss: 0.6939 - val_accuracy: 0.4762 - 11s/epoch - 6s/step
# Epoch 3/40
# 2/2 - 12s - loss: 0.6902 - accuracy: 0.6598 - val_loss: 0.6936 - val_accuracy: 0.5238 - 12s/epoch - 6s/step
# Epoch 4/40
# 2/2 - 12s - loss: 0.6911 - accuracy: 0.6186 - val_loss: 0.6933 - val_accuracy: 0.5238 - 12s/epoch - 6s/step
# Epoch 5/40
# 2/2 - 12s - loss: 0.6896 - accuracy: 0.6082 - val_loss: 0.6928 - val_accuracy: 0.4762 - 12s/epoch - 6s/step
# Epoch 6/40
# 2/2 - 12s - loss: 0.6880 - accuracy: 0.6804 - val_loss: 0.6924 - val_accuracy: 0.5000 - 12s/epoch - 6s/step
# Epoch 7/40
# 2/2 - 12s - loss: 0.6869 - accuracy: 0.6907 - val_loss: 0.6921 - val_accuracy: 0.5000 - 12s/epoch - 6s/step
# Epoch 8/40
# 2/2 - 11s - loss: 0.6874 - accuracy: 0.7010 - val_loss: 0.6918 - val_accuracy: 0.5000 - 11s/epoch - 6s/step
# Epoch 9/40
# 2/2 - 12s - loss: 0.6867 - accuracy: 0.6804 - val_loss: 0.6913 - val_accuracy: 0.5000 - 12s/epoch - 6s/step
# Epoch 10/40
# 2/2 - 12s - loss: 0.6845 - accuracy: 0.6907 - val_loss: 0.6909 - val_accuracy: 0.5000 - 12s/epoch - 6s/step
# Epoch 11/40
# 2/2 - 12s - loss: 0.6844 - accuracy: 0.7320 - val_loss: 0.6905 - val_accuracy: 0.5000 - 12s/epoch - 6s/step
# Epoch 12/40
# 2/2 - 12s - loss: 0.6823 - accuracy: 0.7938 - val_loss: 0.6902 - val_accuracy: 0.5000 - 12s/epoch - 6s/step
# Epoch 13/40
# 2/2 - 12s - loss: 0.6835 - accuracy: 0.7113 - val_loss: 0.6898 - val_accuracy: 0.5000 - 12s/epoch - 6s/step
# Epoch 14/40
# 2/2 - 12s - loss: 0.6811 - accuracy: 0.7216 - val_loss: 0.6894 - val_accuracy: 0.4762 - 12s/epoch - 6s/step
# Epoch 15/40
# 2/2 - 12s - loss: 0.6813 - accuracy: 0.7113 - val_loss: 0.6891 - val_accuracy: 0.4762 - 12s/epoch - 6s/step
# Epoch 16/40
# 2/2 - 12s - loss: 0.6809 - accuracy: 0.7010 - val_loss: 0.6887 - val_accuracy: 0.4762 - 12s/epoch - 6s/step
# Epoch 17/40
# 2/2 - 12s - loss: 0.6765 - accuracy: 0.7629 - val_loss: 0.6882 - val_accuracy: 0.4762 - 12s/epoch - 6s/step
# Epoch 18/40
# 2/2 - 12s - loss: 0.6771 - accuracy: 0.7216 - val_loss: 0.6878 - val_accuracy: 0.4762 - 12s/epoch - 6s/step
# Epoch 19/40
# 2/2 - 12s - loss: 0.6756 - accuracy: 0.7629 - val_loss: 0.6874 - val_accuracy: 0.4762 - 12s/epoch - 6s/step
# Epoch 20/40
# 2/2 - 12s - loss: 0.6740 - accuracy: 0.7526 - val_loss: 0.6868 - val_accuracy: 0.4762 - 12s/epoch - 6s/step
# Epoch 21/40
# 2/2 - 12s - loss: 0.6730 - accuracy: 0.7320 - val_loss: 0.6863 - val_accuracy: 0.4762 - 12s/epoch - 6s/step
# Epoch 22/40
# 2/2 - 12s - loss: 0.6710 - accuracy: 0.7423 - val_loss: 0.6854 - val_accuracy: 0.4762 - 12s/epoch - 6s/step
# Epoch 23/40
# 2/2 - 12s - loss: 0.6688 - accuracy: 0.7732 - val_loss: 0.6846 - val_accuracy: 0.4762 - 12s/epoch - 6s/step
# Epoch 24/40
# 2/2 - 12s - loss: 0.6638 - accuracy: 0.7526 - val_loss: 0.6834 - val_accuracy: 0.4762 - 12s/epoch - 6s/step
# Epoch 25/40
# 2/2 - 12s - loss: 0.6649 - accuracy: 0.7423 - val_loss: 0.6819 - val_accuracy: 0.4762 - 12s/epoch - 6s/step
# Epoch 26/40
# 2/2 - 12s - loss: 0.6596 - accuracy: 0.7835 - val_loss: 0.6810 - val_accuracy: 0.5000 - 12s/epoch - 6s/step
# Epoch 27/40
# 2/2 - 12s - loss: 0.6564 - accuracy: 0.7732 - val_loss: 0.6803 - val_accuracy: 0.4762 - 12s/epoch - 6s/step
# Epoch 28/40
# 2/2 - 15s - loss: 0.6516 - accuracy: 0.7629 - val_loss: 0.6801 - val_accuracy: 0.4762 - 15s/epoch - 7s/step
# Epoch 29/40
# 2/2 - 12s - loss: 0.6485 - accuracy: 0.7835 - val_loss: 0.6798 - val_accuracy: 0.4762 - 12s/epoch - 6s/step
# Epoch 30/40
# 2/2 - 12s - loss: 0.6451 - accuracy: 0.7835 - val_loss: 0.6789 - val_accuracy: 0.4762 - 12s/epoch - 6s/step
# Epoch 31/40
# 2/2 - 12s - loss: 0.6414 - accuracy: 0.8041 - val_loss: 0.6774 - val_accuracy: 0.4762 - 12s/epoch - 6s/step
# Epoch 32/40
# 2/2 - 12s - loss: 0.6368 - accuracy: 0.7835 - val_loss: 0.6762 - val_accuracy: 0.4762 - 12s/epoch - 6s/step
# Epoch 33/40
# 2/2 - 12s - loss: 0.6338 - accuracy: 0.7320 - val_loss: 0.6742 - val_accuracy: 0.4762 - 12s/epoch - 6s/step
# Epoch 34/40
# 2/2 - 12s - loss: 0.6274 - accuracy: 0.7216 - val_loss: 0.6718 - val_accuracy: 0.5000 - 12s/epoch - 6s/step
# Epoch 35/40
# 2/2 - 12s - loss: 0.6173 - accuracy: 0.7526 - val_loss: 0.6694 - val_accuracy: 0.5000 - 12s/epoch - 6s/step
# Epoch 36/40
# 2/2 - 12s - loss: 0.6065 - accuracy: 0.7216 - val_loss: 0.6677 - val_accuracy: 0.5476 - 12s/epoch - 6s/step
# Epoch 37/40
# 2/2 - 12s - loss: 0.6000 - accuracy: 0.7732 - val_loss: 0.6682 - val_accuracy: 0.5238 - 12s/epoch - 6s/step
# Epoch 38/40
# 2/2 - 12s - loss: 0.5918 - accuracy: 0.7423 - val_loss: 0.6732 - val_accuracy: 0.5000 - 12s/epoch - 6s/step
# Epoch 39/40
# 2/2 - 12s - loss: 0.5871 - accuracy: 0.7423 - val_loss: 0.6825 - val_accuracy: 0.4762 - 12s/epoch - 6s/step
# Epoch 40/40
# 2/2 - 12s - loss: 0.5700 - accuracy: 0.7113 - val_loss: 0.6951 - val_accuracy: 0.5000 - 12s/epoch - 6s/step

# %%
history_frame = pd.DataFrame(history.history)
history_frame.loc[:, ['loss','val_loss']].plot()
history_frame.loc[:, ['accuracy','val_accuracy']].plot();

# %%
pred = model.predict(x_test)

for i in range(len(pred)):
    if pred[i] > 0.5:
        pred[i] = 1
    else:
        pred[i] = 0

pred = pred.astype(int)
# Out:
# 2/2 [==============================] - 1s 274ms/step

# %%
#creating a classification report
print(classification_report(y_test, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.42      0.59      0.49        17
#            1       0.61      0.44      0.51        25
#
#     accuracy                           0.50        42
#    macro avg       0.51      0.51      0.50        42
# weighted avg       0.53      0.50      0.50        42

# %% [markdown]
# ## 4.4 Adding a pretrained model

# %% [markdown]
# First we will load a pretrained model named vgg16.

# %%
# load base model
vgg16_weight_path = '../input/keras-pretrained-models/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5'
base_model = VGG16(
    weights=vgg16_weight_path,
    include_top=False, 
    input_shape=(256,256,3)
)

# %% [markdown]
# Now we will replace our convolutional blocks with the vgg16 model.

# %%
model = keras.Sequential([
    
    preprocessing.RandomFlip('horizontal'), # flip left-to-right
    
    base_model, #vgg16
    
    layers.Flatten(),
    layers.Dropout(.25),
    layers.Dense(units=256, activation="relu"),
    layers.Dense(units=1, activation="sigmoid"),
])

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(epsilon=0.01),
    loss='binary_crossentropy',
    metrics=['accuracy']
)

#including early stopping to revent overfitting
early_stopping = keras.callbacks.EarlyStopping(
    patience=40,
    min_delta=0.001,
    restore_best_weights=True,
)

# %%
history = model.fit(
    x = x_train,
    y = y_train,
    validation_data= (x_test,y_test),
    batch_size = 32,
    epochs=40,
    callbacks=[early_stopping],
    verbose=(2),
)
# Out:
# Epoch 1/40
# 4/4 - 143s - loss: 0.1332 - accuracy: 0.9691 - val_loss: 0.6207 - val_accuracy: 0.6905 - 143s/epoch - 36s/step
# Epoch 2/40
# 4/4 - 140s - loss: 0.1766 - accuracy: 0.9175 - val_loss: 0.5526 - val_accuracy: 0.8571 - 140s/epoch - 35s/step
# Epoch 3/40
# 4/4 - 140s - loss: 0.0896 - accuracy: 0.9691 - val_loss: 0.6039 - val_accuracy: 0.8095 - 140s/epoch - 35s/step
# Epoch 4/40
# 4/4 - 146s - loss: 0.0507 - accuracy: 0.9897 - val_loss: 1.8640 - val_accuracy: 0.6429 - 146s/epoch - 36s/step
# Epoch 5/40
# 4/4 - 144s - loss: 0.2505 - accuracy: 0.8763 - val_loss: 2.1296 - val_accuracy: 0.4762 - 144s/epoch - 36s/step
# Epoch 6/40
# 4/4 - 140s - loss: 0.7439 - accuracy: 0.6701 - val_loss: 1.4937 - val_accuracy: 0.6429 - 140s/epoch - 35s/step
# Epoch 7/40
# 4/4 - 140s - loss: 0.3651 - accuracy: 0.8144 - val_loss: 0.5211 - val_accuracy: 0.7619 - 140s/epoch - 35s/step
# Epoch 8/40
# 4/4 - 140s - loss: 0.2394 - accuracy: 0.8969 - val_loss: 0.5490 - val_accuracy: 0.7381 - 140s/epoch - 35s/step
# Epoch 9/40
# 4/4 - 140s - loss: 0.1101 - accuracy: 0.9588 - val_loss: 0.6415 - val_accuracy: 0.7857 - 140s/epoch - 35s/step
# Epoch 10/40
# 4/4 - 140s - loss: 0.0456 - accuracy: 1.0000 - val_loss: 2.3006 - val_accuracy: 0.6667 - 140s/epoch - 35s/step
# Epoch 11/40
# 4/4 - 140s - loss: 0.2900 - accuracy: 0.8660 - val_loss: 1.6945 - val_accuracy: 0.6667 - 140s/epoch - 35s/step
# Epoch 12/40
# 4/4 - 140s - loss: 0.1994 - accuracy: 0.9485 - val_loss: 0.8962 - val_accuracy: 0.6667 - 140s/epoch - 35s/step
# Epoch 13/40
# 4/4 - 142s - loss: 0.3884 - accuracy: 0.7835 - val_loss: 2.3254 - val_accuracy: 0.6667 - 142s/epoch - 36s/step
# Epoch 14/40
# 4/4 - 141s - loss: 0.2144 - accuracy: 0.9278 - val_loss: 1.9943 - val_accuracy: 0.6905 - 141s/epoch - 35s/step
# Epoch 15/40
# 4/4 - 140s - loss: 0.3136 - accuracy: 0.9072 - val_loss: 1.5196 - val_accuracy: 0.5476 - 140s/epoch - 35s/step
# Epoch 16/40
# 4/4 - 141s - loss: 0.2449 - accuracy: 0.9072 - val_loss: 0.7699 - val_accuracy: 0.6905 - 141s/epoch - 35s/step
# Epoch 17/40
# 4/4 - 140s - loss: 0.1692 - accuracy: 0.9381 - val_loss: 1.4313 - val_accuracy: 0.7143 - 140s/epoch - 35s/step
# Epoch 18/40
# 4/4 - 140s - loss: 0.1371 - accuracy: 0.9381 - val_loss: 1.0008 - val_accuracy: 0.7857 - 140s/epoch - 35s/step
# Epoch 19/40
# 4/4 - 140s - loss: 0.0120 - accuracy: 1.0000 - val_loss: 1.0956 - val_accuracy: 0.7857 - 140s/epoch - 35s/step
# Epoch 20/40
# 4/4 - 140s - loss: 0.0136 - accuracy: 1.0000 - val_loss: 1.2772 - val_accuracy: 0.7857 - 140s/epoch - 35s/step
# Epoch 21/40
# 4/4 - 145s - loss: 0.0153 - accuracy: 1.0000 - val_loss: 1.7213 - val_accuracy: 0.7857 - 145s/epoch - 36s/step
# Epoch 22/40
# 4/4 - 141s - loss: 0.0020 - accuracy: 1.0000 - val_loss: 2.1350 - val_accuracy: 0.7619 - 141s/epoch - 35s/step
# Epoch 23/40
# 4/4 - 141s - loss: 0.0036 - accuracy: 1.0000 - val_loss: 2.1719 - val_accuracy: 0.7857 - 141s/epoch - 35s/step
# Epoch 24/40
# 4/4 - 140s - loss: 1.8459e-04 - accuracy: 1.0000 - val_loss: 2.2368 - val_accuracy: 0.7857 - 140s/epoch - 35s/step
# Epoch 25/40
# 4/4 - 140s - loss: 4.9266e-04 - accuracy: 1.0000 - val_loss: 2.3432 - val_accuracy: 0.7857 - 140s/epoch - 35s/step
# Epoch 26/40
# 4/4 - 140s - loss: 2.9246e-04 - accuracy: 1.0000 - val_loss: 2.4766 - val_accuracy: 0.7857 - 140s/epoch - 35s/step
# Epoch 27/40
# 4/4 - 140s - loss: 3.6799e-04 - accuracy: 1.0000 - val_loss: 2.6048 - val_accuracy: 0.7857 - 140s/epoch - 35s/step
# Epoch 28/40
# 4/4 - 140s - loss: 5.7749e-05 - accuracy: 1.0000 - val_loss: 2.7222 - val_accuracy: 0.7857 - 140s/epoch - 35s/step
# Epoch 29/40
# 4/4 - 140s - loss: 8.4327e-04 - accuracy: 1.0000 - val_loss: 2.6366 - val_accuracy: 0.7857 - 140s/epoch - 35s/step
# Epoch 30/40
# 4/4 - 140s - loss: 6.0290e-05 - accuracy: 1.0000 - val_loss: 2.5433 - val_accuracy: 0.7619 - 140s/epoch - 35s/step
# Epoch 31/40
# 4/4 - 141s - loss: 1.7275e-04 - accuracy: 1.0000 - val_loss: 2.5175 - val_accuracy: 0.7619 - 141s/epoch - 35s/step
# Epoch 32/40
# 4/4 - 140s - loss: 1.0536e-04 - accuracy: 1.0000 - val_loss: 2.5205 - val_accuracy: 0.7619 - 140s/epoch - 35s/step
# Epoch 33/40
# 4/4 - 140s - loss: 9.5146e-05 - accuracy: 1.0000 - val_loss: 2.5408 - val_accuracy: 0.7619 - 140s/epoch - 35s/step
# Epoch 34/40
# 4/4 - 145s - loss: 1.2598e-04 - accuracy: 1.0000 - val_loss: 2.5829 - val_accuracy: 0.7857 - 145s/epoch - 36s/step
# Epoch 35/40
# 4/4 - 140s - loss: 3.4007e-05 - accuracy: 1.0000 - val_loss: 2.6171 - val_accuracy: 0.7857 - 140s/epoch - 35s/step
# Epoch 36/40
# 4/4 - 140s - loss: 4.3575e-05 - accuracy: 1.0000 - val_loss: 2.6526 - val_accuracy: 0.7857 - 140s/epoch - 35s/step
# Epoch 37/40
# 4/4 - 141s - loss: 4.6913e-05 - accuracy: 1.0000 - val_loss: 2.6855 - val_accuracy: 0.7857 - 141s/epoch - 35s/step
# Epoch 38/40
# 4/4 - 141s - loss: 2.0380e-05 - accuracy: 1.0000 - val_loss: 2.7102 - val_accuracy: 0.7857 - 141s/epoch - 35s/step
# Epoch 39/40
# 4/4 - 141s - loss: 2.4899e-05 - accuracy: 1.0000 - val_loss: 2.7300 - val_accuracy: 0.7857 - 141s/epoch - 35s/step
# Epoch 40/40
# 4/4 - 142s - loss: 1.6684e-05 - accuracy: 1.0000 - val_loss: 2.7472 - val_accuracy: 0.7857 - 142s/epoch - 35s/step

# %%
history_frame = pd.DataFrame(history.history)
history_frame.loc[:, ['loss','val_loss']].plot()
history_frame.loc[:, ['accuracy','val_accuracy']].plot();

# %%
model._name="BrainTumorDetectionVGG16_Modification"
model.summary()
# Out:
# Model: "BrainTumorDetectionVGG16_Modification"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  random_flip_12 (RandomFlip)  (None, 256, 256, 3)      0
#
#  vgg16 (Functional)          (None, 8, 8, 512)         14714688
#
#  flatten_18 (Flatten)        (None, 32768)             0
#
#  dropout_18 (Dropout)        (None, 32768)             0
#
#  dense_36 (Dense)            (None, 256)               8388864
#
#  dense_37 (Dense)            (None, 1)                 257
#
# =================================================================
# Total params: 23,103,809
# Trainable params: 23,103,809
# Non-trainable params: 0
# _________________________________________________________________

# %%
pred = model.predict(x_test)

for i in range(len(pred)):
    if pred[i] > 0.5:
        pred[i] = 1
    else:
        pred[i] = 0

pred = pred.astype(int)
# Out:
# 2/2 [==============================] - 17s 5s/step

# %% [markdown]
# # 5. Results

# %% [markdown]
# ## 5.1 Results table

# %% [markdown]
# The idea we set out with was to start with a baseline model and add to that model and improve the accuracy with each step. Here is the results of each step:
#
# Model                      |     Accuracy
# ---------------------------|---------------
# Baseline                   |     86%
# Adding Data Agumentation   |     89%
# Adding Pretrained Model    |     98%

# %% [markdown]
# # 6. Conclusion

# %% [markdown]
# ## 6.1 Summary

# %% [markdown]
# We set out with the task of coming up with a model that could predict if a brain MRI image has a tumor or not. We used the keras libary to create a convolutional neural network. We used that as a baseline. From there we added data agumentation to add data. We then added a pretrained model to get our final results.

# %% [markdown]
# ## 6.2 Brief thoughts on results

# %% [markdown]
# I was pleasantly surprised by the results. I was not sure if we would be able to get an accuracy above 90% with such a small dataset. The transfer learning worked really well!

# %% [markdown]
# ## 6.3 Future Work

# %% [markdown]
# Next step would be to apply this model to a much larger dataset. A much larger data set would allow the model to train off of more cases allowing the model to generalize better. Another step would be to include the different types of tumors and their stages, and to focus on early detection.
